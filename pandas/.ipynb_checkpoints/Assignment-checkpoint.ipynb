# %%
import pandas as pd
df=pd.read_csv("IRIS.csv")
df2=df.copy()

print(df2.head(10))

print(df2.shape,type(df2))

print(df2.describe())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa
# (150, 5) <class 'pandas.core.frame.DataFrame'>
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# ...

# %%
#df2=df2[df2["petal_length"]>4.5 and df["species"]=="Iris-virginica"]
# the above code gives error becuase firstly ans works with series 1d only
# and [] these brackets wont work except 1 d data we also need ()
new1=df2[df2["petal_length"]>4.5]
# this works fine since one condition is there 
new=df2[(df2["petal_length"]>4.5) & (df2["species"]=="Iris-virginica")]

# %%
df.groupby("species")["sepal_length"].mean()
# Out:
# species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: sepal_length, dtype: float64

# %%
df.groupby("species").aggregate(
    avg_sepal_lenght=("sepal_length","mean"),
    Maximum_petal_width=("petal_width","max"),
    Standard_deviation_of_sepal_width=("sepal_width","std")
)
# Out:
#                  avg_sepal_lenght  Maximum_petal_width  \
# species
# Iris-setosa                 5.006                  0.6
# Iris-versicolor             5.936                  1.8
# Iris-virginica              6.588                  2.5
#
#                  Standard_deviation_of_sepal_width
# species
# Iris-setosa                               0.381024
# Iris-versicolor                           0.313798
# Iris-virginica                            0.322497

# %%
df["petal_ratio"] = df["petal_length"] / df["petal_width"]
df=df.assign(petal_ratio=df["petal_length"]/df["petal_width"])
df.groupby("species")["petal_ratio"].mean()
# Out:
# species
# Iris-virginica    2.783389
# Name: petal_ratio, dtype: float64

# %%
df=pd.read_csv("Titanic-Dataset.csv")
df2=df[["Name", "Sex", "Age","Fare","Survived"]]
df2
# Out:
#                                                   Name     Sex   Age     Fare  \
# 0                              Braund, Mr. Owen Harris    male  22.0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  female  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                             Allen, Mr. William Henry    male  35.0   8.0500
# ..                                                 ...     ...   ...      ...
# 886                              Montvila, Rev. Juozas    male  27.0  13.0000
# 887                       Graham, Miss. Margaret Edith  female  19.0  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN  23.4500
# 889                              Behr, Mr. Karl Howell    male  26.0  30.0000
# 890                                Dooley, Mr. Patrick    male  32.0   7.7500
#
#      Survived
# 0           0
# ...

# %%
data=df2[(df2["Sex"]=="female") & (df2["Fare"]>30)]
data
# Out:
#                                                   Name     Sex   Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN
# ..                                                 ...     ...   ...
# 853                          Lines, Miss. Mary Conover  female  16.0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
#
#          Fare  Survived
# 1     71.2833         1
# 3     53.1000         1
# 9     30.0708         1
# 25    31.3875         1
# ...

# %%
df.groupby("Pclass").agg(
    Survival_rate=("Survived","mean"),
    Average_Fare=("Fare","mean"),
    Average_age=("Age","mean")
)
# Out:
#         Survival_rate  Average_Fare  Average_age
# Pclass
# 1            0.629630     84.154687    38.233441
# 2            0.472826     20.662183    29.877630
# 3            0.242363     13.675550    25.140620
