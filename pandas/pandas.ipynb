# %% [markdown]
# PANDAS
#
# pandas is built on numpy
#
# pandas is suitable for data analysis

# %%
import pandas as pd

# %%
info={
    "Name":["Rahul","Harshita","Rahul"],
    "CGPA":[9.5,9.5,8.5]
}
df=pd.DataFrame(info) # DataFrames basically are labelled array
print(df)# you can have self defined labels as well
# Out:
#        Name  CGPA
# 0     Rahul   9.5
# 1  Harshita   9.5
# 2     Rahul   8.5

# %% [markdown]
# SERIES
# series is a 1-D labelled array
#
# series is an individual column

# %%
s=pd.Series([1,2,3,4,5])
print(s)
print(type(s))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>
